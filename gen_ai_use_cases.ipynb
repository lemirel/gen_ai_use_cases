# %% [markdown]
# <a href="https://colab.research.google.com/github/lemirel/gen_ai_use_cases/blob/main/gen_ai_use_cases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade --quiet google-cloud-aiplatform
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 64.2 MB/s eta 0:00:00

# %%
from inspect import cleandoc
from IPython.display import display, Markdown

import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig

# %%
PROJECT = !gcloud config get-value project
PROJECT_ID = PROJECT[0]
REGION = "us-west1"
vertexai.init(project=PROJECT_ID, location=REGION)

# %%
model = GenerativeModel("gemini-pro")

# %%
creative_gen_config = GenerationConfig(temperature=1, top_p=0.8)

# %%
prompt = "What are some strategies for overcoming writer's block?"

response = model.generate_content(prompt,
                                  generation_config=creative_gen_config)
print(response.text)
# Out:
# ## Strategies for Overcoming Writer's Block:
#
# Writer's block can be a frustrating experience for any writer, but don't worry, there are many strategies you can employ to overcome it and get your creative juices flowing again. Here are some ideas to get you started:
#
# **Change your environment:**
#
# * **Find a new location:** Sometimes a change of scenery can be all it takes to spark new ideas. Try writing in a coffee shop, library, park, or even your backyard.
# * **Listen to music:** Putting on some instrumental music or nature sounds can help you focus and get in the mood to write.
# * **Take a break:** Step away from your work for a while and do something else you enjoy. Go for a walk, take a nap, or read a book. When you come back to your writing, you may find that you have a fresh perspective.
#
# **Freewriting:**
#
# * **Set a timer for 10 minutes and write non-stop.** Don't worry about grammar, spelling, or making sense. Just write whatever comes to mind. This can be a great way to get your thoughts flowing and overcome the initial hurdle of starting to write.
# * **Use prompts:** There are many online resources that offer writing prompts to help you get started. You can also use a random word generator or simply close your eyes and choose the first word that comes to mind.
#
# **Outline your ideas:**
#
# * **Instead of trying to write a perfect first draft, try outlining your ideas first.** This can help you to organize your thoughts and figure out the direction you want your writing to take.
# * **Use mind maps, bullet points, or any other method that works for you.**
#
# **Talk to someone:**
#
# * **Talking about your writing can help you to gain new insights and perspectives.** Discuss your ideas with a friend, family member, or writing group.
# * **Getting feedback from others can be helpful, even if it's just to hear someone else's thoughts on your work.**
#
# **Read:**
#
# * **Reading the work of other writers can inspire you and help you to learn new techniques.**
# * **Pay attention to how other writers approach different genres, styles, and topics.**
#
# **Remember, writer's block is a temporary condition.** Don't get discouraged, just keep trying different strategies until you find something that works for you.
#
# **Here are some additional tips:**
#
# * **Set realistic goals:** Don't try to write a novel in a day. Start with small goals, such as writing for 15 minutes or 500 words.
# * **Reward yourself:** When you reach your goals, reward yourself with something you enjoy.
# * **Don't be afraid to experiment:** Try new writing styles, genres, and techniques.
# * **Most importantly, have fun!** Writing should be enjoyable, so don't put too much pressure on yourself.
#
# I hope these strategies help you to overcome writer's block and get back to writing with confidence.

# %%
prompt = "Provide ten interview questions for the role of prompt engineer."

response = model.generate_content(prompt,
                                  generation_config=creative_gen_config)
print(response.text)
# Out:
# ## Ten Interview Questions for a Prompt Engineer:
#
# **Technical Skills:**
#
# 1. **How do you approach the task of breaking down a complex task or problem into smaller, more manageable prompts?**
# 2. **Describe your experience with different prompt engineering techniques, such as few-shot learning, zero-shot learning, and in-context learning.**
# 3. **Explain how you evaluate the quality of your prompts. What metrics do you use, and how do you interpret them?**
# 4. **What are some of the challenges you have faced in prompt engineering, and how have you overcome them?**
# 5. **How do you stay up-to-date with the latest research and advancements in prompt engineering?**
#
# **Problem-Solving and Communication:**
#
# 6. **Describe a time when you had to troubleshoot a problem with a prompt that wasn't working as expected. How did you identify the issue and resolve it?**
# 7. **How do you collaborate with other team members, such as data scientists, engineers, and product managers, to ensure that your prompts are aligned with the overall goals of the project?**
# 8. **How do you explain complex technical concepts to non-technical stakeholders?**
# 9. **Can you provide an example of a time when you had to adapt your communication style to effectively interact with someone from a different background or expertise level?**
#
# **Additional:**
#
# 10. **What are your thoughts on the ethical considerations involved in prompt engineering, such as bias and fairness? How do you ensure that your prompts are responsible and unbiased?**
#
# **Bonus:**
#
# * **Have you worked with any specific NLP models or frameworks for prompt engineering? If so, which ones and how did you use them?**
# * **Can you share a portfolio of your previous work as a prompt engineer, or provide examples of specific prompts you have created?**
# * **What are your salary expectations for this role?**
#
# **Note:** These are just a few examples, and the specific questions you ask will depend on the specific requirements of the role and the experience level of the candidate.

# %%
predictable_gen_config = GenerationConfig(temperature=0.1, top_p=0.1)

# %%
prompt = """
Given a user's input, classify their intent, such as "finding information", "making a reservation", or "placing an order". \n
user input: Hi, can you please book a table for two at Juan for May 1?
"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# ## Intent Classification: Making a Reservation
#
# The user's input indicates an intent to make a reservation. They specify the following details:
#
# * **Restaurant:** Juan
# * **Date:** May 1
# * **Party size:** Two people

# %%
prompt = """
What is the topic for a given news headline? \n
- business \n
- entertainment \n
- health \n
- sports \n
- technology \n\n

Text: Pixel 7 Pro Expert Hands On Review. \n
The answer is: technology \n

Text: Quit smoking? \n
The answer is: health \n

Text: Birdies or bogeys? Top 5 tips to hit under par \n
The answer is: sports \n

Text: Relief from local minimum-wage hike looking more remote \n
The answer is: business \n

Text: You won't guess who just arrived in Bari, Italy for the movie premiere. \n
The answer is:
"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# entertainment

# %%
import pandas as pd
from sklearn.metrics import classification_report

review_data_df = pd.DataFrame(
    {
        "review": [
            "i love this product. it does have everything i am looking for!",
            "all i can say is that you will be happy after buying this product",
            "its way too expensive and not worth the price",
            "i am feeling okay. its neither good nor too bad.",
        ],
        "sentiment_groundtruth": ["positive", "positive", "negative", "neutral"],
    }
)

review_data_df
# Out:
#                                               review sentiment_groundtruth
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral

# %%
def get_sentiment(row):
    prompt = f"""Classify the sentiment of the following review as "positive", "neutral" or "negative". Return only the classification.
                review: {row}
              """
    response = model.generate_content(
        contents=prompt, generation_config=predictable_gen_config
    ).text
    return response


review_data_df["sentiment_prediction"] = review_data_df["review"].apply(get_sentiment)
review_data_df
# Out:
#                                               review sentiment_groundtruth  \
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral
#
#   sentiment_prediction
# 0             positive
# 1             positive
# 2             negative
# 3              neutral

# %%
report = classification_report(
    review_data_df["sentiment_groundtruth"], review_data_df["sentiment_prediction"]
)
Markdown(report)
# Out:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       1.00      1.00      1.00         1
#     positive       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
predictable_gen_config = GenerationConfig(temperature=0.1, top_p=0.1)

# %%
prompt = """
Provide a very short summary, no more than three sentences, for the following article:

Our quantum computers work by manipulating qubits in an orchestrated fashion that we call quantum algorithms.
The challenge is that qubits are so sensitive that even stray light can cause calculation errors — and the problem worsens as quantum computers grow.
This has significant consequences, since the best quantum algorithms that we know for running useful applications require the error rates of our qubits to be far lower than we have today.
To bridge this gap, we will need quantum error correction.
Quantum error correction protects information by encoding it across multiple physical qubits to form a "logical qubit," and is believed to be the only way to produce a large-scale quantum computer with error rates low enough for useful calculations.
Instead of computing on the individual qubits themselves, we will then compute on logical qubits. By encoding larger numbers of physical qubits on our quantum processor into one logical qubit, we hope to reduce the error rates to enable useful quantum algorithms.

Summary:

"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# ## Summary:
#
# Quantum computers are sensitive to errors, which limits their ability to run useful algorithms. Quantum error correction aims to solve this by encoding information across multiple qubits, creating "logical qubits" with lower error rates. This will enable the development of large-scale quantum computers capable of performing complex calculations.

# %%
prompt = """
Provide a very short summary in four bullet points for the following article:

Our quantum computers work by manipulating qubits in an orchestrated fashion that we call quantum algorithms.
The challenge is that qubits are so sensitive that even stray light can cause calculation errors — and the problem worsens as quantum computers grow.
This has significant consequences, since the best quantum algorithms that we know for running useful applications require the error rates of our qubits to be far lower than we have today.
To bridge this gap, we will need quantum error correction.
Quantum error correction protects information by encoding it across multiple physical qubits to form a "logical qubit," and is believed to be the only way to produce a large-scale quantum computer with error rates low enough for useful calculations.
Instead of computing on the individual qubits themselves, we will then compute on logical qubits. By encoding larger numbers of physical qubits on our quantum processor into one logical qubit, we hope to reduce the error rates to enable useful quantum algorithms.

Bullet points:

"""

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
Markdown(response.text)
# Out:
# ## Summary of the article in 4 bullet points:
#
# * **Quantum computers are sensitive:** Even small disturbances like stray light can cause errors in calculations.
# * **Error rates are a problem:** Current error rates are too high for running useful quantum algorithms.
# * **Quantum error correction is the solution:** It protects information by encoding it across multiple qubits, creating a "logical qubit" with lower error rates.
# * **Encoding physical qubits into logical qubits:** This reduces error rates and enables the use of complex quantum algorithms.

# %%
prompt = """
Please generate a summary of the following conversation and at the end summarize the to-do's for the support Agent:

Customer: Hi, I'm Larry, and I received the wrong item.

Support Agent: Hi, Larry. How would you like to see this resolved?

Customer: That's alright. I want to return the item and get a refund, please.

Support Agent: Of course. I can process the refund for you now. Can I have your order number, please?

Customer: It's [ORDER NUMBER].

Support Agent: Thank you. I've processed the refund, and you will receive your money back within 14 days.

Customer: Thank you very much.

Support Agent: You're welcome, Larry. Have a good day!

Summary:
"""

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
Markdown(response.text)
# Out:
# ## Summary of Conversation:
#
# * **Customer:** Larry received the wrong item.
# * **Desired Resolution:** Larry wants to return the item and receive a refund.
# * **Resolution:** The support agent processed the refund for the order.
# * **Refund Timeline:** Larry will receive the refund within 14 days.
#
# ## To-Dos for Support Agent:
#
# * **None.** The support agent has already completed the necessary actions.

# %%
order = "We need eight grilled cheese sandwiches. Two with swiss cheese, three with muenster, three with cheddar."

prompt = """
    Break the customer's order into individual items with keys for the following fields:
    - item_name
    - cheese_selection

    Order:
    {order_field}
""".format(order_field=order)

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# ```json
# [
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Swiss"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Swiss"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   }
# ]
# ```

# %%
prompt = """Q: Who was President of the United States in 1955?
              Which party did he belong to?
            A:
        """
response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# ## Answer:
#
# In 1955, **Dwight D. Eisenhower** was President of the United States. He belonged to the **Republican Party**.
#
# Here's some additional information about Eisenhower's presidency in 1955:
#
# * He was in the second year of his first term, having been elected in 1952.
# * He was a popular figure, known for his leadership during World War II and his moderate political views.
# * Some of the key events of his presidency in 1955 included:
#     * The signing of the Civil Rights Act of 1955, which outlawed discrimination in voting.
#     * The start of the Cold War arms race, with the Soviet Union testing its first hydrogen bomb.
#     * The Montgomery Bus Boycott, which began in December 1955 and lasted for over a year.
#
# I hope this information is helpful! Let me know if you have any other questions.

# %%
context = """
Storage and content policy \n
How durable is my data in Cloud Storage? \n
Cloud Storage is designed for 99.999999999% (11 9's) annual durability, which is appropriate for even primary storage and
business-critical applications. This high durability level is achieved through erasure coding that stores data pieces redundantly
across multiple devices located in multiple availability zones.
Objects written to Cloud Storage must be redundantly stored in at least two different availability zones before the
write is acknowledged as successful. Checksums are stored and regularly revalidated to proactively verify that the data
integrity of all data at rest as well as to detect corruption of data in transit. If required, corrections are automatically
made using redundant data. Customers can optionally enable object versioning to add protection against accidental deletion.
"""

question = "How is high availability achieved?"

prompt = f"""Answer the question given in the contex below:
Context: {context}?\n
Question: {question} \n
Answer:
"""

print("[Prompt]")
print(prompt)

print("[Response]")
response = model.generate_content(contents=prompt, generation_config=predictable_gen_config)
print(response.text)
# Out:
# [Prompt]
# Answer the question given in the contex below:
# Context:
# Storage and content policy
#
# How durable is my data in Cloud Storage?
#
# Cloud Storage is designed for 99.999999999% (11 9's) annual durability, which is appropriate for even primary storage and
# business-critical applications. This high durability level is achieved through erasure coding that stores data pieces redundantly
# across multiple devices located in multiple availability zones.
# Objects written to Cloud Storage must be redundantly stored in at least two different availability zones before the
# write is acknowledged as successful. Checksums are stored and regularly revalidated to proactively verify that the data
# integrity of all data at rest as well as to detect corruption of data in transit. If required, corrections are automatically
# made using redundant data. Customers can optionally enable object versioning to add protection against accidental deletion.
# ?
#
# Question: How is high availability achieved?
#
# Answer:
#
# [Response]
# ## High Availability in Cloud Storage
#
# Cloud Storage achieves high availability through a combination of redundancy and proactive data integrity checks:
#
# **Redundancy:**
#
# * **Erasure coding:** Data is split into pieces and stored redundantly across multiple devices in different availability zones. This ensures that even if some devices fail, the data remains accessible.
# * **Object replication:** Objects are written to at least two different availability zones before the write is acknowledged as successful. This further protects against data loss in case of a zone outage.
#
# **Data Integrity Checks:**
#
# * **Checksums:** Checksums are stored for each data piece and regularly revalidated. This allows for proactive detection of data corruption and automatic correction using redundant data.
# * **Object versioning:** Customers can optionally enable object versioning to restore previous versions of an object in case of accidental deletion or modification.
#
# These measures ensure that Cloud Storage provides high availability and data durability, making it suitable for even mission-critical applications.
